# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import keras
import tensorflow
from sklearn import model_selection

# %%
data = pd.read_csv('data.csv')

# %%
data.head()
# Out:
#     X1   X2   X3   X4   X5   X6   X7   X8   X9  X10  ...  X170  X171  X172  \
# 0  135  190  229  223  192  125   55   -9  -33  -38  ...   -17   -15   -31
# 1  386  382  356  331  320  315  307  272  244  232  ...   164   150   146
# 2  -32  -39  -47  -37  -32  -36  -57  -73  -85  -94  ...    57    64    48
# 3 -105 -101  -96  -92  -89  -95 -102 -100  -87  -79  ...   -82   -81   -80
# 4   -9  -65  -98 -102  -78  -48  -16    0  -21  -59  ...     4     2   -12
#
#    X173  X174  X175  X176  X177  X178  y
# 0   -77  -103  -127  -116   -83   -51  4
# 1   152   157   156   154   143   129  1
# 2    19   -12   -30   -35   -35   -36  5
# 3   -77   -85   -77   -72   -69   -65  5
# 4   -32   -41   -65   -83   -89   -73  5
#
# [5 rows x 179 columns]

# %%
data.drop(columns=['Unnamed: 0'], inplace = True)

# %%
y = data.iloc[:, -1]

# %%
X = data.iloc[:, :data.shape[1] - 1]

# %%
cnn_par = {
    'window': [3, 7, 11],
    'dropout': [0.1, 0.2, 0.5],
    'epochs': [25, 35]
}

# %%
from keras.layers import Dense
from keras.layers import Dropout
from keras.layers import GlobalAveragePooling1D
from keras.layers.convolutional import Conv1D
from keras.layers.convolutional import MaxPooling1D
from keras.models import Sequential
from keras.wrappers.scikit_learn import KerasClassifier

# %%
X_train, X_test, y_train, y_test = model_selection.train_test_split(X, y, test_size = 0.33, stratify = y)

# %%
from sklearn import preprocessing

# %%
scaler_train = preprocessing.StandardScaler()
scaler_train.fit(X_train)
X_train_cnn = scaler_train.transform(X_train)
X_test_cnn = scaler_train.transform(X_test)

# %%
filter_cnn = 64
number_of_classes = len(np.unique(y))
input_shape = (X_train.shape[1], 1)

# %%
np.unique(y)
# Out:
# array([1, 2, 3, 4, 5], dtype=int64)

# %%
number_of_classes
# Out:
# 5

# %%
y_train[:10]
# Out:
# 10186    2
# 8636     2
# 6599     4
# 3827     1
# 4446     2
# 1061     3
# 9872     3
# 10162    2
# 11057    1
# 9683     5
# Name: y, dtype: int64

# %%
from keras import utils
y_train = utils.to_categorical(y_train, number_of_classes)
y_test = utils.to_categorical(y_test, number_of_classes)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-30-747e959b089c> in <module>
#       1 from keras import utils
# ----> 2 y_train = utils.to_categorical(y_train, number_of_classes)
#       3 y_test = utils.to_categorical(y_test, number_of_classes)
#
# ~\anaconda3\lib\site-packages\keras\utils\np_utils.py in to_categorical(y, num_classes, dtype)
#      50     n = y.shape[0]
#      51     categorical = np.zeros((n, num_classes), dtype=dtype)
# ---> 52     categorical[np.arange(n), y] = 1
#      53     output_shape = input_shape + (num_classes,)
#      54     categorical = np.reshape(categorical, output_shape)
#
# IndexError: index 5 is out of bounds for axis 1 with size 5

# %%
pool = 3

# %%
def mreza(window, dropout):
    model = Sequential()
    model.add(Conv1D(filter_cnn, window, activation='relu', input_shape=input_shape))
    model.add(Conv1D(filter_cnn, window, activation='relu'))
    model.add(MaxPooling1D(pool))
    model.add(Conv1D(filter_cnn * 2, window, activation='relu'))
    model.add(Conv1D(filter_cnn * 2, window, activation='relu'))
    model.add(GlobalAveragePooling1D())
    model.add(Dropout(dropout))
    model.add(Dense(number_of_classes, activation='softmax'))
    model.compile(loss='sparse_categorical_crossentropy', optimizer='adam', metrics=['accuracy'])
    return model

# %%
from keras.wrappers.scikit_learn  import KerasClassifier
def get_estimator(window = 3, dropout = 0.5):
    return KerasClassifier(build_fn=mreza, window = window, dropout=dropout)

# %%
grid_cnn = model_selection.GridSearchCV(get_estimator(), param_grid=cnn_par, scoring='accuracy', cv=10, return_train_score=True)

# %%
grid_cnn.fit(X_train, y_train)
# Out:
# C:\Users\vbakarevic\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:536: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# ValueError: Error when checking input: expected conv1d_1471_input to have 3 dimensions, but got array with shape (6934, 178)
#
#   FitFailedWarning)
# C:\Users\vbakarevic\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:536: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# ValueError: Error when checking input: expected conv1d_1475_input to have 3 dimensions, but got array with shape (6934, 178)
#
#   FitFailedWarning)
# C:\Users\vbakarevic\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:536: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# ...

# %%
grid_cnn.best_score_
# Out:
# nan
